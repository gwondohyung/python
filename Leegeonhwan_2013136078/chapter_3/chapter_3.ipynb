# %% [markdown]
# # 3장 시카고 샌드위치 맛집 분석

# %% [markdown]
# ### 3-1 웹데이터를 가져오는 Beautiful Soup 익히기

# %% [markdown]
#  - bs4라는 모듈로 BeautifulSoup라는 함수 가져오기

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# - prettify() : 들여쓰기가 실행되어 html이 보기 좋아진다.
# - html.parser : 웹페이지의 내용을 해석하고 구조를 분석하는 프로그램

# %%
page = open("../chapter_3/03. test_first.html",'r').read()
soup = BeautifulSoup(page,'html.parser')
print(soup)
print('---------------------------------------------------------------------')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>
# ---------------------------------------------------------------------
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
# ...

# %% [markdown]
#   - children : 하위 태그를 출력한다.
#   - parents : 상위 태그부터 출력한다.
#
#     html > head, body > p

# %%
list(soup.children)
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]
print(html)
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>, '\n', <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>, '\n']

# %%
body=list(html.children)[3]
print(body)
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
html.parent
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
soup.html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %% [markdown]
# - find_all : 입력한 태그에 대하여 모두 출력해주는 명령
# - find : 입력한 태그에 대하여 첫 태그만 출력해주는 명령

# %%
soup.find_all('p')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>, <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>, <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find('p')
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find_all('p',class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all('p',id='first')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %% [markdown]
# - next_sibling : 다음 위치의 태그를 가져온다. (리스트를 보면 순서를 알 수 있다.)

# %%
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
soup.head.next_sibling
# Out:
# '\n'

# %%
list(soup)
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
soup.head.next_sibling.next_sibling
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %% [markdown]
# - get_text : 태그에 있는 텍스트만을 가져온다.(줄바꿈도 포함된다.)

# %%
soup.find_all('p')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>, <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>, <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
for each_tag in soup.find_all('p'):
    print(each_tag.get_text())
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %% [markdown]
# - print로 출력 안 할 경우 줄바꿈이 \n으로 표현된다.

# %%
body.get_text()
# Out:
# '\n\n\n                Happy PinkWink.\n                PinkWink\n\n\n                Happy Data Science.\n                Python\n\n\n\n\n                Data Science is funny.\n            \n\n\n\n                All I need is Love.\n            \n\n'

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %% [markdown]
# - href속성값 이용하기
#
#  (참고) a태그 : 클릭 가능한 링크를 의미한다.

# %%
links = soup.find_all('a')
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
for each in links:
    href = each['href']
    text = each.string
    print(text + ' -> ' + href)
# Out:
# PinkWink -> http://www.pinkwink.kr
# Python -> https://www.python.org

# %%
for each in links:
    href = each['id']
    text = each.get_text()
    print(text + ' -> ' + href)
# Out:
# PinkWink -> pw-link
# Python -> py-link

# %% [markdown]
# ### 3-2 크롬 개발자 도구를 이용해서 원하는 태그 찾기

# %% [markdown]
# - urllib.request : url을 열 수 있도록 도와주는 모듈
# - 금융정보사이트 : http://info.finance.naver.com/marketindex

# %%
from urllib.request import urlopen

# %%
url = "http://info.finance.naver.com/marketindex/"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")
print(soup.prettify())
# Out:
# <script language="javascript" src="http://finance.naver.com/template/head_js.nhn?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="/js/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <script language="JavaScript" src="/js/flashObject.js?20171213045922">
#  </script>
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#         <h3 class="h_lst">
# ...

# %%
soup.find_all('span', 'value')
# Out:
# [<span class="value">1,059.70</span>,
#  <span class="value">994.88</span>,
#  <span class="value">1,301.10</span>,
#  <span class="value">168.47</span>,
#  <span class="value">106.5500</span>,
#  <span class="value">1.2272</span>,
#  <span class="value">1.4037</span>,
#  <span class="value">89.8500</span>,
#  <span class="value">63.51</span>,
#  <span class="value">1551.09</span>,
#  <span class="value">1332.8</span>,
#  <span class="value">45457.78</span>]

# %%
soup.find_all('span','value')[0].string
# Out:
# '1,059.70'

# %% [markdown]
# ### 3-3 실전: 시카고 샌드위치 맛집 소개 사이트에 접근하기

# %% [markdown]
# - 시카코 샌드위치 맛집 사이트 : http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

url = 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'
html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

print(soup)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <!-- Urbis magnitudo. Fabulas magnitudo. -->
# <meta charset="utf-8"/>
# <style>a.edit_from_site {display: none !important;}</style>
# <title>
#   The 50 Best Sandwiches in Chicago |
#   Chicago magazine
#       |  November 2012
#     </title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable = no" name="viewport">
# <meta content="Our list of Chicago’s 50 best sandwiches, ranked in order of deliciousness" name="description"/>
# <!-- <meta name="description" content="Our list of Chicago’s 50 best sandwiches, ranked in order of deliciousness"> -->
# <meta content="sandwiches, dining" name="keywords"/>
# <meta content="37873197144" property="fb:pages">
# <link href="//cloud.typography.com" rel="dns-prefetch"/>
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# ...

# %%
print(soup.find_all('div', 'sammy'))
# Out:
# [<div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br>
# Old Oak Tap<br>
# <em>Read more</em> </br></br></a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">2</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
# Au Cheval<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">3</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
# Xoco<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">4</div>
# ...

# %% [markdown]
# - div에서 sammy태그를 찾으면 리스트 형태로 나오고 이 리스트의 길이를 구하면 맛집의 개수를 알 수 있다.

# %%
len(soup.find_all('div', 'sammy'))
# Out:
# 50

# %% [markdown]
# - 인덱싱과 슬라이싱으로 범위 지정 가능

# %%
print(soup.find_all('div', 'sammy')[0:2])
# Out:
# [<div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br>
# Old Oak Tap<br>
# <em>Read more</em> </br></br></a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">2</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
# Au Cheval<br/>
# <em>Read more</em> </a></div>
# </div>]

# %% [markdown]
# ### 3-4 접근한 웹 페이지에서 원하는 데이터 추출하고 정리하기

# %%
tmp_one = soup.find_all('div','sammy')[0]
print(tmp_one)
type(tmp_one)
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br>
# Old Oak Tap<br>
# <em>Read more</em> </br></br></a></div>
# </div>
# bs4.element.Tag

# %% [markdown]
# - bs4.element.Tag가 나오면 다시 태그찾기가 가능하고 원하는 정보를 얻을 수 있다.(find, find_all)

# %%
tmp_one.find(class_='sammyRank')
# Out:
# <div class="sammyRank">1</div>

# %%
print(tmp_one.find(class_='sammyRank').string)
print(tmp_one.find(class_='sammyRank').get_text())
# Out:
# 1
# 1

# %% [markdown]
# - 메뉴와 가게 이름도 가져오기 가능

# %%
tmp_one.find(class_='sammyListing').get_text()
# Out:
# 'BLT\r\nOld Oak Tap\nRead more '

# %%
tmp_one.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %% [markdown]
# - 정규식을 이용해 메뉴이름과 가게이름 분리하기

# %%
import re
tmp_string = tmp_one.find(class_='sammyListing').get_text()
re.split(('\n|\r\n'), tmp_string)

print(re.split(('\n|\r\n'), tmp_string)[0])
print(re.split(('\n|\r\n'), tmp_string)[1])
# Out:
# BLT
# Old Oak Tap

# %% [markdown]
# - urljoin : 상대경로와 절대경로를 하나로 통합하기 위해 사용(절대경로로 통합된다.)
#       - 상대경로 : 현재 폴더부터 경로 표시
#       - 절대경로 : 가장 상위 폴더부터 경로 표시

# %%
from urllib.request import urljoin

rank = []
main_menu = []
cafe_name = []
url_add=[]

list_soup = soup.find_all('div', 'sammy')
for item in list_soup:
    rank.append(item.find(class_='sammyRank').get_text())
    tmp_string = item.find(class_='sammyListing').get_text()
    main_menu.append(re.split(('\n|\r\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n|\r\n'), tmp_string)[1])
    url_add.append(urljoin(url, item.find('a')['href']))
print(rank[:5])
print(main_menu[:5])
print(cafe_name[:5])
url_add[:5]
# Out:
# ['1', '2', '3', '4', '5']
# ['BLT', 'Fried Bologna', 'Woodland Mushroom', 'Roast Beef', 'PB&L']
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']
# ['http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/']

# %%
print(len(rank))
print(len(main_menu))
print(len(cafe_name))
print(len(url_add))
# Out:
# 50
# 50
# 50
# 50

# %% [markdown]
# - 웹페이지에서 가져온 정보 pandas로 정리하기

# %%
import pandas as pd
data = {'Rank':rank, 'Menu':main_menu, 'Cafe':cafe_name, 'URL':url_add}
df=pd.DataFrame(data)
df.head()
# Out:
#                      Cafe               Menu Rank  \
# 0             Old Oak Tap                BLT    1
# 1               Au Cheval      Fried Bologna    2
# 2                    Xoco  Woodland Mushroom    3
# 3               Al’s Deli         Roast Beef    4
# 4  Publican Quality Meats               PB&L    5
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %% [markdown]
# - 원하는 형태로 정리하기

# %%
df = pd.DataFrame(data, columns =['Rank','Cafe', 'Menu','URL'])
df.head(6)
# Out:
#   Rank                             Cafe                         Menu  \
# 0    1                      Old Oak Tap                          BLT
# 1    2                        Au Cheval                Fried Bologna
# 2    3                             Xoco            Woodland Mushroom
# 3    4                        Al’s Deli                   Roast Beef
# 4    5           Publican Quality Meats                         PB&L
# 5    6  Hendrickx Belgian Bread Crafter  Belgian Chicken Curry Salad
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 5  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
df.to_csv('../chapter_3/03. best_sandwiches_list_chicago.csv', sep=',', encoding='UTF-8')

# %% [markdown]
# ### 3-5 다수의 웹페이지에 자동으로 접근해서 원하는 정보 가져오기

# %% [markdown]
# - 시카고 샌드위치 맛집 사이트 : http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/

# %%
df=pd.read_csv('../chapter_3/03. best_sandwiches_list_chicago.csv',index_col=0)
df.head()
# Out:
#    Rank                    Cafe               Menu  \
# 0     1             Old Oak Tap                BLT
# 1     2               Au Cheval      Fried Bologna
# 2     3                    Xoco  Woodland Mushroom
# 3     4               Al’s Deli         Roast Beef
# 4     5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 1  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %% [markdown]
# - 목록에서 저장되어있는 url 가져오기

# %%
html = urlopen(df['URL'][0])
soup_tmp=BeautifulSoup(html, "html.parser")
print(soup_tmp)
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en">
# <head>
# <!-- Urbis magnitudo. Fabulas magnitudo. -->
# <meta charset="utf-8"/>
# <style>a.edit_from_site {display: none !important;}</style>
# <title>
#   1. Old Oak Tap BLT |
#   Chicago magazine
#       |  November 2012
#     </title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable = no" name="viewport">
# <meta content="“Truly inspired.”" name="description"/>
# <!-- <meta name="description" content="&#8220;Truly inspired.&#8221;"> -->
# <meta content="" name="keywords"/>
# <meta content="37873197144" property="fb:pages">
# <link href="//cloud.typography.com" rel="dns-prefetch"/>
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//media.chicagomag.com" rel="dns-prefetch"/>
# <link href="//ox-d.godengo.com/" rel="dns-prefetch"/>
# ...

# %% [markdown]
# - 웹페이지에서 url확인하고 가격, 주소, 전화번호 정보 가져오기

# %%
print(soup_tmp.find('p','addy'))
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
price_tmp = soup_tmp.find('p','addy').get_text()
print(price_tmp)
# Out:
# $10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com

# %%
print(price_tmp.split())
print(price_tmp.split()[0])
print(price_tmp.split()[0][:-1])
print(price_tmp.split()[-1])
# Out:
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']
# $10.
# $10
# theoldoaktap.com

# %%
' '.join(price_tmp.split()[1:-2])
# Out:
# '2109 W. Chicago Ave.,'

# %% [markdown]
# - url 각 정보를 리스트에 담기
# - lxml : 보다 크기가 크고 많은 파일을 다룰 때 편하고 빠르게 처리해 준다.

# %%
price = []
address = []
for n in df.index[:50]:
    html = urlopen(df['URL'][n])
    soup_tmp = BeautifulSoup(html, 'lxml')
    
    gettings = soup_tmp.find('p','addy').get_text()
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))
print(price)
print(address)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'URL'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-6c79232154c2> in <module>()
#       2 address = []
# ...

# %% [markdown]
# ### 3-6 상태 진행바 적용해서 샌드위치 페이지 50개에 접근하기

# %% [markdown]
# - tqdm : conda install -c conda-forge tqdm

# %%
from tqdm import tqdm_notebook
price = []
address = []
for n in tqdm_notebook(df.index):
    html = urlopen(df['URL'][n])
    soup_tmp = BeautifulSoup(html, 'html.parser')
    
    gettings = soup_tmp.find('p','addy').get_text()
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'URL'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-832dec9aaa39> in <module>()
#       3 address = []
# ...

# %%
len(price), len(address), len(df)
# Out:
# (0, 0, 50)

# %% [markdown]
# - loc: 라벨을 인덱싱한다.

# %%
df['Price'] = price
df['Address'] = address

df= df.loc[:, ['Rank', 'Cafe', 'Menu', 'Price','Address']]
df.set_index('Rank',inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-b27766b33daa> in <module>()
# ----> 1 df['Price'] = price
#       2 df['Address'] = address
#       3
#       4 df= df.loc[:, ['Rank', 'Cafe', 'Menu', 'Price','Address']]
#       5 df.set_index('Rank',inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ...

# %%
df.to_csv('../chapter_3/03.best_sandwiches_list_chicago2.csv',sep=',',encoding='UTF-8')

# %% [markdown]
# ### 3-7 맛집 위치를 지도에 표기하기

# %% [markdown]
# - folium : 위치정보를 시각화한다.
# - numpy : 과학계산을 위한 라이브러리

# %%
import folium
import pandas as pd
import googlemaps
import numpy as np

# %%
df=pd.read_csv('../chapter_3/03.best_sandwiches_list_chicago2.csv', index_col=0)
df.head(5)
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address        lat        lng
# Rank
# 1        2109 W. Chicago Ave.,  41.895605 -87.679961
# 2         800 W. Randolph St.,  41.884658 -87.647667
# 3            445 N. Clark St.,  41.890618 -87.630933
# 4     914 Noyes St., Evanston,  42.058322 -87.683748
# 5          825 W. Fulton Mkt.,  41.886566 -87.648575

# %%
gmaps_key = "AIzaSyD7bztzI-Jcb8nrPxX5cmqLQLCchUiNS-Q"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
lat = [] #위도
lng = [] #경도

for n in tqdm_notebook(df.index):
    if df['Address'][n] !='Multiple':
        target_name = df['Address'][n]+', ' +'Cicago'
        gmaps_output = gmaps.geocode(target_name)
        print(gmaps_output)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    else:
        lat.append(np.nan)
        lng.append(np.nan)
print(lat)
print(lng)
# Out:
# ...
# [{'address_components': [{'long_name': '2109', 'short_name': '2109', 'types': ['street_number']}, {'long_name': 'West Chicago Avenue', 'short_name': 'W Chicago Ave', 'types': ['route']}, {'long_name': 'West Town', 'short_name': 'West Town', 'types': ['neighborhood', 'political']}, {'long_name': 'Chicago', 'short_name': 'Chicago', 'types': ['locality', 'political']}, {'long_name': 'Cook County', 'short_name': 'Cook County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Illinois', 'short_name': 'IL', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '60622', 'short_name': '60622', 'types': ['postal_code']}, {'long_name': '4821', 'short_name': '4821', 'types': ['postal_code_suffix']}], 'formatted_address': '2109 W Chicago Ave, Chicago, IL 60622, USA', 'geometry': {'location': {'lat': 41.8956049, 'lng': -87.67996149999999}, 'location_type': 'ROOFTOP', 'viewp
# ...

# %% [markdown]
# - df에 위도와 경도를 추가하기

# %%
df['lat'] = lat
df['lng'] = lng
df
# Out:
#                                  Cafe  \
# Rank
# 1                         Old Oak Tap
# 2                           Au Cheval
# 3                                Xoco
# 4                           Al’s Deli
# 5              Publican Quality Meats
# 6     Hendrickx Belgian Bread Crafter
# 7                              Acadia
# 8                   Birchwood Kitchen
# 9                      Cemitas Puebla
# 10                               Nana
# 11                          Lula Cafe
# 12                         Ricobene’s
# 13                       Frog n Snail
# 14                   Crosby’s Kitchen
# 15                    Longman & Eagle
# 16                               Bari
# 17                            Manny’s
# 18                             Eggy’s
# 19                      Old Jerusalem
# 20               Mindy’s HotChocolate
# 21                Olga’s Delicatessen
# 22       Dawali Mediterranean Kitchen
# 23                          Big Jones
# ...

# %%
mapping = folium.Map(location =[df['lat'].mean(), df['lng'].mean()],zoom_start=11)
folium.Marker([df['lat'].mean(),df['lng'].mean()],popup='center').add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapping = folium.Map(location =[df['lat'].mean(), df['lng'].mean()],zoom_start=11)
for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n],df['lng'][n]],popup=df['Cafe'][n]).add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3-8 네이버 영화 평점 기준 영화의 평점 변화 확인하기

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# - 네이버 영화 : https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20180329

# %%
from urllib.request import urlopen
url = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20180329"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20180329" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div','tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=106360" title="위대한 쇼맨">위대한 쇼맨</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=10102" title="사운드 오브 뮤직">사운드 오브 뮤직</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=18847" title="타이타닉">타이타닉</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=31013" title="빌리 엘리어트">빌리 엘리어트</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=151728" title="코코">코코</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=144379" title="러빙 빈센트">러빙 빈센트</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=152160" title="킹 오브 프리즘 한국어판">킹 오브 프리즘 한국어판</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=169349" title="뽀로로 극장판 공룡섬 대모험">뽀로로 극장판 공룡섬 대모험</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=146489" title="패딩턴 2">패딩턴 2</a>
#  </div>, <div class="tit5">
# ...

# %% [markdown]
# - 영화 사이트에서 제목찾기

# %%
soup.find_all('div','tit5')[0].a.string
# Out:
# '위대한 쇼맨'

# %% [markdown]
# - 영화 사이트에서 포인트찾기

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.38'

# %% [markdown]
# - freq로 출력형태 바꿀수 있음(A,B,C,D,H,T 등)

# %%
date = pd.date_range('2017-12-1',periods=100, freq ='D')
date
# Out:
# DatetimeIndex(['2017-12-01', '2017-12-02', '2017-12-03', '2017-12-04',
#                '2017-12-05', '2017-12-06', '2017-12-07', '2017-12-08',
#                '2017-12-09', '2017-12-10', '2017-12-11', '2017-12-12',
#                '2017-12-13', '2017-12-14', '2017-12-15', '2017-12-16',
#                '2017-12-17', '2017-12-18', '2017-12-19', '2017-12-20',
#                '2017-12-21', '2017-12-22', '2017-12-23', '2017-12-24',
#                '2017-12-25', '2017-12-26', '2017-12-27', '2017-12-28',
#                '2017-12-29', '2017-12-30', '2017-12-31', '2018-01-01',
#                '2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-06', '2018-01-07', '2018-01-08', '2018-01-09',
#                '2018-01-10', '2018-01-11', '2018-01-12', '2018-01-13',
#                '2018-01-14', '2018-01-15', '2018-01-16', '2018-01-17',
#                '2018-01-18', '2018-01-19', '2018-01-20', '2018-01-21',
# ...

# %% [markdown]
# - 날짜를 기준으로 영화 제목과 포인트

# %% [markdown]
# - strftime() : 날짜/시간을 스트링 형태로 변환해준다.

# %%
import urllib
from tqdm import tqdm_notebook
movie_date =[]
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "http://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"        #url형태로 인코딩 된다.
    response = urlopen(html.format(date=urllib.parse.quote(today.strftime('%Y%m%d'))))  #4자리의 연도와 월, 일을 문자열로 변환
    soup = BeautifulSoup(response, "html.parser")
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie.head()
# Out:
#         date        name point
# 0 2017-12-01    뷰티풀 투모로우  9.36
# 1 2017-12-01    아이 캔 스피크  9.34
# 2 2017-12-01  다시 태어나도 우리  9.32
# 3 2017-12-01          록키  9.31
# 4 2017-12-01      저수지 게임  9.29

# %% [markdown]
# - point를 합하기 위해 문자가 아닌 숫자 형태로 바꾸기

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4237 entries, 0 to 4236
# Data columns (total 3 columns):
# date     4237 non-null datetime64[ns]
# name     4237 non-null object
# point    4237 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 99.4+ KB

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4237 entries, 0 to 4236
# Data columns (total 3 columns):
# date     4237 non-null datetime64[ns]
# name     4237 non-null object
# point    4237 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 99.4+ KB

# %% [markdown]
# - pivot_table을 이용하여 포인트 합구하기

# %%
import numpy as np
movie_unique = pd.pivot_table(movie,index=['name'], aggfunc = np.sum)
movie_best=movie_unique.sort_values(by='point', ascending =False)
movie_best.head()
# Out:
#                   point
# name
# 러빙 빈센트           919.11
# 내 사랑             898.76
# 라라랜드             799.76
# 위대한 쇼맨           762.83
# 뽀로로 극장판 공룡섬 대모험  715.68

# %%
tmp = movie.query('name == ["위대한 쇼맨"]')
tmp
# Out:
#            date    name  point
# 934  2017-12-20  위대한 쇼맨   9.63
# 982  2017-12-21  위대한 쇼맨   9.65
# 1024 2017-12-22  위대한 쇼맨   9.63
# 1065 2017-12-23  위대한 쇼맨   9.60
# 1107 2017-12-24  위대한 쇼맨   9.60
# 1156 2017-12-25  위대한 쇼맨   9.58
# 1201 2017-12-26  위대한 쇼맨   9.54
# 1243 2017-12-27  위대한 쇼맨   9.51
# 1293 2017-12-28  위대한 쇼맨   9.49
# 1341 2017-12-29  위대한 쇼맨   9.48
# 1390 2017-12-30  위대한 쇼맨   9.45
# 1437 2017-12-31  위대한 쇼맨   9.44
# 1485 2018-01-01  위대한 쇼맨   9.44
# 1524 2018-01-02  위대한 쇼맨   9.43
# 1563 2018-01-03  위대한 쇼맨   9.43
# 1593 2018-01-04  위대한 쇼맨   9.43
# 1624 2018-01-05  위대한 쇼맨   9.42
# 1656 2018-01-06  위대한 쇼맨   9.42
# 1690 2018-01-07  위대한 쇼맨   9.41
# 1724 2018-01-08  위대한 쇼맨   9.40
# 1759 2018-01-09  위대한 쇼맨   9.40
# 1796 2018-01-10  위대한 쇼맨   9.40
# 1827 2018-01-11  위대한 쇼맨   9.40
# 1861 2018-01-12  위대한 쇼맨   9.39
# 1898 2018-01-13  위대한 쇼맨   9.40
# 1935 2018-01-14  위대한 쇼맨   9.40
# 1971 2018-01-15  위대한 쇼맨   9.40
# 2006 2018-01-16  위대한 쇼맨   9.39
# 2043 2018-01-17  위대한 쇼맨   9.39
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.plot(tmp['date'],tmp['point'])
plt.legend(loc='best')   #라벨의 위치 설정
plt.grid() #격자 나누기
plt.show()

# %% [markdown]
# ### 3-9 영화별 날짜 변화에 따른 평점 변화 확인하기

# %%
movie_pivot = pd.pivot_table(movie, index=['date'],columns=['name'], values=['point'])
movie_pivot.head()
# Out:
#            point                                                          \
# name         10분 12 솔져스 1987 1급기밀 50가지 그림자: 해방 7년-그들이 없는 언론   7호실 B급 며느리
# date
# 2017-12-01  8.89    NaN  NaN  NaN          NaN          NaN   NaN    NaN
# 2017-12-02  8.89    NaN  NaN  NaN          NaN          NaN  6.96    NaN
# 2017-12-03   NaN    NaN  NaN  NaN          NaN          NaN  6.91    NaN
# 2017-12-04   NaN    NaN  NaN  NaN          NaN          NaN  6.88    NaN
# 2017-12-05   NaN    NaN  NaN  NaN          NaN          NaN   NaN    NaN
#
#                                ...                                             \
# name         가위손 가장 따뜻한 색, 블루  ...  하이큐!! 승자와 패자 하이큐!! 재능과 센스 해피 데스데이 행복을 찾아서
# date                           ...
# 2017-12-01   NaN          NaN  ...           NaN          NaN    8.37     8.9
# 2017-12-02   NaN          NaN  ...           NaN          NaN    8.36     8.9
# 2017-12-03   NaN          NaN  ...           NaN          NaN    8.36     8.9
# ...

# %% [markdown]
# - point를 없애서 다시 정리

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()
movie_pivot.head()
# Out:
# name         10분  12 솔져스  1987  1급기밀  50가지 그림자: 해방  7년-그들이 없는 언론   7호실  \
# date
# 2017-12-01  8.89     NaN   NaN   NaN           NaN           NaN   NaN
# 2017-12-02  8.89     NaN   NaN   NaN           NaN           NaN  6.96
# 2017-12-03   NaN     NaN   NaN   NaN           NaN           NaN  6.91
# 2017-12-04   NaN     NaN   NaN   NaN           NaN           NaN  6.88
# 2017-12-05   NaN     NaN   NaN   NaN           NaN           NaN   NaN
#
# name        B급 며느리   가위손  가장 따뜻한 색, 블루  ...   하이큐!! 승자와 패자  하이큐!! 재능과 센스  \
# date                                    ...
# 2017-12-01     NaN   NaN           NaN  ...            NaN           NaN
# 2017-12-02     NaN   NaN           NaN  ...            NaN           NaN
# 2017-12-03     NaN   NaN           NaN  ...            NaN           NaN
# 2017-12-04     NaN  9.25           NaN  ...            NaN           NaN
# 2017-12-05     NaN   NaN           NaN  ...            NaN           NaN
#
# ...

# %% [markdown]
# - 서로 다른 커널에 대한 한글 문제 해결

# %%
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/fonts/malgun.ttf"
if platform.system() == 'Darwin':  #커널 버젼
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family = font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
movie_pivot.plot(y=['위대한 쇼맨', '범죄도시', '신과함께-죄와 벌', '툼레이더'],figsize=(12,6))
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
